# %%
import pandas as pd

# %%
import matplotlib as plt
df=pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head(3)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
df.tail(3)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.sample(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 179  female        group D            some high school      standard
# 618    male        group D             master's degree      standard
# 679    male        group D                some college  free/reduced
# 259  female        group C             master's degree  free/reduced
# 921  female        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 179               completed          97            100            100
# 618                    none          95             81             84
# 679                    none          63             61             60
# 259               completed          65             81             81
# 921                    none          35             53             46

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.rename(columns={"lunch":"break","math score":"math grade"})
# Out:
#      gender race/ethnicity parental level of education         break  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math grade  reading score  writing score
# ...

# %%
pd.set_option=("display.max_row",None)
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.describe(include="all")
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  reading score  writing score
# count                     1000  1000.00000    1000.000000    1000.000000
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df["math score"].plot(kind="line")
# Out:
# <Axes: >

# %%
df.dropna()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.fillna(50)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
print(df.duplicated)
# Out:
# <bound method DataFrame.duplicated of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df["math score"].mean()
# Out:
# 66.089

# %%
df["math score"].mode()
# Out:
# 0    65
# Name: math score, dtype: int64

# %%
df["math score"].median()
# Out:
# 66.0

# %%
df["math score"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='math score'>

# %%
df["math score"].plot(kind="line")
# Out:
# <Axes: >

# %%
df["math score"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["math score"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["math score"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='math score'>

# %%
df["math score"].value_counts().plot(kind="line",color="red")
# Out:
# <Axes: xlabel='math score'>

# %%
df.plot(color="black")
# Out:
# <Axes: >

# %%
df["math score"].std()
# Out:
# 15.163080096009468

# %%
df.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df[df["math score"].isnull()]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score]
# Index: []

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
x = df["math score"].fillna(500)

# %%
df["math score"]=df["math score"].fillna(df["math score"].mean())

# %%
df[df["math score"].isnull()]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score]
# Index: []

# %%
df.loc[[6,8,9,4]]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 6  female        group B                some college      standard
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 6               completed          88             95             92
# 8               completed          64             64             67
# 9                    none          38             60             50
# 4                    none          76             78             75

# %%
df.iloc[[6,8]]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 6  female        group B                some college      standard
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 6               completed          88             95             92
# 8               completed          64             64             67

# %%
df.groupby("math score").describe()
# Out:
#            reading score                                                  \
#                    count       mean       std   min    25%    50%    75%
# math score
# 0                    1.0  17.000000       NaN  17.0  17.00   17.0   17.0
# 8                    1.0  24.000000       NaN  24.0  24.00   24.0   24.0
# 18                   1.0  32.000000       NaN  32.0  32.00   32.0   32.0
# 19                   1.0  38.000000       NaN  38.0  38.00   38.0   38.0
# 22                   1.0  39.000000       NaN  39.0  39.00   39.0   39.0
# ...                  ...        ...       ...   ...    ...    ...    ...
# 96                   3.0  95.333333  5.033223  90.0  93.00   96.0   98.0
# 97                   6.0  91.833333  6.554896  82.0  88.25   92.5   96.0
# 98                   3.0  91.000000  7.810250  86.0  86.50   87.0   93.5
# 99                   3.0  93.333333  6.506407  87.0  90.00   93.0   96.5
# 100                  7.0  97.857143  3.078342  92.0  96.50  100.0  100.0
#
# ...

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.fillna(14)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.dropna()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[4:6]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 4    male        group C                some college  standard
# 5  female        group B          associate's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 4                    none          76             78             75
# 5                    none          71             83             78

# %%
df[2:4:6]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 2                    none          90             95             93

# %%
kind="bar"

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
x = df
